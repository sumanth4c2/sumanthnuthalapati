# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanth4c2/sumanthnuthalapati/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Pandas.ipynb")
print(df)
# Out:
# Empty DataFrame
# Columns: [{"nbformat":4, nbformat_minor:0, metadata:{"colab":{"name":"Pandas.ipynb", provenance:[{"file_id":"1bUs_M3IjQ8GX9_7uyE537sy1ooGWqrTs", timestamp:1580838912936}], collapsed_sections:[], authorship_tag:"ABX9TyPS1VcUv/DcVwWPjuLuaY8Z"}, kernelspec:{"name":"python3", display_name:"Python 3"}}, cells:[{"cell_type":"markdown", metadata:{"id":"iN8R4xgmV9EE", colab_type:"text"}, source:[""]}, {"cell_type":"markdown", metadata:{"id":"nIhlh58xQ0tM", colab_type:"text"}.1, source:["Python Pandas - DataFrame\n", \n, ![image.png](data:image/png;base64,...)]}, {"cell_type":"markdown".1, metadata:{"id":"OlIWhKpLQ9w3", colab_type:"text"}.2, source:["![image.png](......)"]}, {"cell_type":"markdown".2, metadata:{"id":"hWVKHgMxRWcf", colab_type:"text"}.3, source:["A pandas DataFrame can be created using the following constructor −\n", \n.1, pandas.DataFrame( data, index, columns, dtype, copy)\n]}, {"cell_type":"markdown".3, metadata:{"id":"1pSNZI2bRdo-", colab_type:"text"}.4, source:["![image.png](data:image/png;base64.1, ...)"]}, {"cell_type":"markdown".4, metadata:{"id":"kNeZ7djvRzLA", colab_type:"text"}.5, source:["Create DataFrame\n", A pandas DataFrame can be created using various inputs like −\n, \n.2, **Lists**\n, **dict**\n, **Series**\n, **Numpy ndarrays**\n, **Another DataFrame**]}, {"cell_type":"code", metadata:{"id":"zgoJQl0LKT-1", colab_type:"code", colab:{}}, source:["import pandas as pd\n", data = [1,2,3,4,5]\n, df = pd.DataFrame(data)\n, print(df)], execution_count:0, outputs:[]}, {"cell_type":"code".1, metadata:{"id":"IRUKFlO1Q73L", colab_type:"code".1, colab:{}}.1, source:[""], execution_count:0.1, outputs:[]}.1, {"cell_type":"markdown".5, metadata:{"id":"DIkyi-P5KUP1", colab_type:"text"}.6, source:["Create a DataFrame from Lists"]}, {"cell_type":"code".2, metadata:{"id":"0gCVUmhVKRpf", colab_type:"code".2, colab:{}}.2, source:["#Example 2\n", \n.3, import pandas as pd\n, data = [['Alex',10],['Bob',12],['Clarke',13]]\n, df = pd.DataFrame(data,columns=['Name','Age'])\n, print(df)\n, \n.4, \n.5, \n], execution_count:0.2, outputs:[]}.2, {"cell_type":"code".3, metadata:{"id":"5qSe0Q8hKtMw", colab_type:"code".3, colab:{}}.3, source:["#Example 3\n", \n.6, import pandas as pd\n.1, data = [['Alex',10],['Bob',12],['Clarke',13]]\n.1, df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)\n, print(df)].1, execution_count:0.3, outputs:[]}.3, {"cell_type":"code".4, metadata:{"id":"rMytMAl1K1GE", colab_type:"code".4, colab:{}}.4, source:[""].1, execution_count:0.4, ...]
# Index: []
#
# [0 rows x 386 columns]
